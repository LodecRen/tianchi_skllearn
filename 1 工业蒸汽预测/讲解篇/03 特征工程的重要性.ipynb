# %% [markdown]
# # 特征工程
# 从原始数据提取特征的一个过程:
# * 特征使用
# * 特征获取
# * 特征处理
# * 特征选择
# * 特征监控
#
# <img src="attachment:1a31a821-9c75-47a3-b831-e064030f5df3.png" width='600'>

# %% [markdown]
# ## 1 数据预处理和特征处理
# ### 预处理:
# 数据采集, 数据清洗, 数据采样

# %% [markdown]
# (1) 数据采集
# * 探讨哪些数据对最后的预测有益
# * 如何采集这一类数据
# * 线上部署时,是否快捷
#
# (2) 数据清洗
# * 去除不规范数据, 异常点...
#
# (3) 数据采样
# 在数据采集, 清洗后,正负样本数是不均匀的, 所以进行数据采样. 正负样本本通常用于描述二分类问题中的两个类别

# %% [markdown]
# ### 特征处理:
# 标准化, 区间缩放法, 归一化, 定量特征二值化, 定性特征哑编码, 缺失值处理和数据转换

# %% [markdown]
# ## 2 特征降维
# 将高维数据点映射到低维的空间中, 降维本质是一个学习的映射, $f: x→y$
# 常用方法:
# * 特征选择
# * 特征降维

# %% [markdown]
# ### 特征选择
# 特征选择是在数据分析和简单建模中最常用的特征降维手段, 其比较简单粗暴,即映射函数直接将不重要的特征删除,不过这样会造成特征信息的丢失,不利于模型精度。
# 由于数据分析以抓住主要影响因子为主,变量越少越有利于分析,因此特征选择常用于统计分析模型中;
# 在超高维数据分析或者建模预处理中也会经常使用,如基因序列建模。
# <img src='attachment:54a1532e-c6c1-4b5e-a7f7-e1f691a1d945.png' width='900'>

# %% [markdown]
# (1) 特征选择的方法
# * 过滤法
# * 包装法
# * 嵌入法
#
# <img src='attachment:b1b153d7-9595-4146-a25f-ab90d8fe96b7.png' width='800'>
